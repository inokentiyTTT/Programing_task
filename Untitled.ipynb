# %%
import argparse
import pandas as pd
from statsmodels.tsa.arima_model import ARIMA
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
                        FutureWarning)
warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
                        FutureWarning)

# my_parser = argparse.ArgumentParser()
# my_parser.add_argument('-D', action='store', type=str, required=True)
# args = my_parser.parse_args()
# plt.style.use("fivethirtyeight")
# 
# print(df.head())

# %%
# df = pd.read_csv('SG.csv', header=0, parse_dates=[0], index_col=0, squeeze=True)
df = pd.read_csv('SG.csv',delimiter=';')

# %%
df.head()
# Out:
#                         Time   Consumption  Grid consumption  Grid backflow  \
# 0  2022-03-05T08:30:00+01:00  64271.779712      59611.639881            0.0
# 1  2022-03-05T09:00:00+01:00  73479.560484      68433.723571            0.0
# 2  2022-03-05T09:30:00+01:00  83463.478524      72519.254048            0.0
# 3  2022-03-05T10:00:00+01:00  77097.835603      71244.783571            0.0
# 4  2022-03-05T10:30:00+01:00  80078.206568      71724.207800            0.0
#
#    PV generation  Battery charging  Battery discharging
# 0    1155.158681               0.0          3461.813704
# 1    1594.969056               0.0          4079.943209
# 2    2015.292333               0.0          9322.759101
# 3    2144.178222               0.0          4177.316192
# 4    4037.172414               0.0          4617.098633

# %%
s1=df.plot(x='Time', y='Consumption',figsize=(20, 4),  rot=30)
# s1.plot(figsize=(4, 10))
# (s1.get_xticklabels(), rotation=45)

# %%
s2=df.plot(x='Time', y='Grid consumption',figsize=(20, 4),  rot=30)

# %%
s2=df.plot(x='Time', y='PV generation',figsize=(20, 4),  rot=30)

# %%
from statsmodels.tsa.arima_model import ARIMA
import warnings
warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
                        FutureWarning)
warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
                        FutureWarning)
# 1,1,2 ARIMA Model
model = ARIMA((dfs.Consumption), order=(0,1,2))
model_fit = model.fit(disp=0)
print(model_fit.summary())
# Out:
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:          D.Consumption   No. Observations:                 1436
# Model:                 ARIMA(0, 1, 2)   Log Likelihood              -15044.458
# Method:                       css-mle   S.D. of innovations           8584.369
# Date:                Fri, 08 Apr 2022   AIC                          30096.916
# Time:                        09:52:02   BIC                          30117.995
# Sample:                             1   HQIC                         30104.786
#
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                  32.4164    259.034      0.125      0.900    -475.280     540.113
# ma.L1.D.Consumption     0.1220      0.026      4.621      0.000       0.070       0.174
# ma.L2.D.Consumption     0.0215      0.025      0.853      0.394      -0.028       0.071
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# MA.1           -2.8319           -6.1964j            6.8129           -0.3182
# MA.2           -2.8319           +6.1964j            6.8129            0.3182
# -----------------------------------------------------------------------------
# c:\programs\python\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# c:\programs\python\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# c:\programs\python\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'

# %%
# Plot residual errors
# residuals = pd.DataFrame(model_fit.resid)
# fig, ax = plt.subplots(1,2)
# residuals.plot(title="Residuals", ax=ax[0])
# # residuals.plot(kind='kde', title='Density', ax=ax[1])
# plt.show()

# %%
model_fit.plot_predict()

# %%
def fit_to_model(dts):
    df.isnull().sum()
    dfs=df.dropna(axis=0)
    model = ARIMA((dts), order=(0,1,2))
    model_fit = model.fit(disp=0)
    print(model_fit.summary())
    model_fit.plot_predict()

# %%
fit_to_model((dfs.Consumption))
# Out:
# c:\programs\python\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# c:\programs\python\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# c:\programs\python\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:          D.Consumption   No. Observations:                 1436
# Model:                 ARIMA(0, 1, 2)   Log Likelihood              -15044.458
# Method:                       css-mle   S.D. of innovations           8584.369
# Date:                Fri, 08 Apr 2022   AIC                          30096.916
# Time:                        11:15:41   BIC                          30117.995
# Sample:                             1   HQIC                         30104.786
#
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                  32.4164    259.034      0.125      0.900    -475.280     540.113
# ma.L1.D.Consumption     0.1220      0.026      4.621      0.000       0.070       0.174
# ma.L2.D.Consumption     0.0215      0.025      0.853      0.394      -0.028       0.071
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# MA.1           -2.8319           -6.1964j            6.8129           -0.3182
# MA.2           -2.8319           +6.1964j            6.8129            0.3182
# -----------------------------------------------------------------------------

# %%
df.isnull().sum()
dfs=df.dropna(axis=0)

# %%
df['Consumption']
# Out:
# 0        64271.779712
# 1        73479.560484
# 2        83463.478524
# 3        77097.835603
# 4        80078.206568
#             ...
# 1436     30475.396429
# 1437     39011.790411
# 1438     38536.480855
# 1439     87121.507746
# 1440    110821.688532
# Name: Consumption, Length: 1441, dtype: float64

# %%
delimiter=';'
